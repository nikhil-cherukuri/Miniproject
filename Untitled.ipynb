# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelBinarizer, StandardScaler, OneHotEncoder
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score, KFold
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from pprint import pprint
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.
# C:\Users\HOME\anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\HOME\anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Importing the dataset
dataset = pd.read_csv('Phenotypic_V1_0b_preprocessed1.csv')

# Creating dataset with selected features only
my_dataset = dataset.loc[:,['SUB_ID','SEX','HANDEDNESS_CATEGORY','AGE_AT_SCAN','FIQ','VIQ','PIQ','ADOS_TOTAL',
                            'ADI_R_SOCIAL_TOTAL_A','ADI_R_VERBAL_TOTAL_BV','ADI_RRB_TOTAL_C','ADI_R_ONSET_TOTAL_D',
                            'SUB_IN_SMP','CURRENT_MED_STATUS','DSM_IV_TR']]

# %%
# The handedness field contains categorical data, since it has considerably large number of missing values, NaN's are replaced by string 'n/a' (not available) as a new category 
my_dataset.HANDEDNESS_CATEGORY = my_dataset.HANDEDNESS_CATEGORY.fillna('n/a')
        
# Replacing other missing values with mean of respective columns
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
my_dataset.iloc[:, 3:12] = imputer.fit_transform(my_dataset.iloc[:, 3:12])
        
# Dropping all rows which still contain any NaN values
my_dataset = my_dataset.dropna()
my_dataset.head(10)
# Out:
#    SUB_ID  SEX HANDEDNESS_CATEGORY  AGE_AT_SCAN    FIQ    VIQ    PIQ  \
# 0   50002    1                Ambi        16.77  103.0  116.0   89.0
# 1   50003    1                   R        24.45  124.0  128.0  115.0
# 2   50004    1                   R        19.09  113.0  108.0  117.0
# 3   50005    2                   R        13.73  119.0  117.0  118.0
# 4   50006    1                   L        13.37  109.0   99.0  119.0
# 5   50007    1                   R        17.78  110.0  106.0  112.0
# 6   50008    1                   R        32.45  123.0  123.0  114.0
# 7   50009    1                   R        33.86  126.0  118.0  128.0
# 8   50010    1                   L        35.20   81.0   81.0   93.0
# 9   50011    1                   L        16.93  111.0  101.0  120.0
#
#    ADOS_TOTAL  ADI_R_SOCIAL_TOTAL_A  ADI_R_VERBAL_TOTAL_BV  ADI_RRB_TOTAL_C  \
# 0   12.000000             16.000000               9.000000         5.000000
# 1   13.000000             27.000000              22.000000         5.000000
# 2   18.000000             19.000000              12.000000         5.000000
# 3   12.000000             23.000000              19.000000         3.000000
# 4   12.000000             13.000000              10.000000         4.000000
# 5   17.000000             21.000000              14.000000         9.000000
# 6   16.000000             24.000000              20.000000        10.000000
# 7   10.000000             20.000000              11.000000         3.000000
# 8   11.062651             19.767196              15.791557         6.084656
# 9   13.000000             24.000000              14.000000         6.000000
#
#    ADI_R_ONSET_TOTAL_D  SUB_IN_SMP  CURRENT_MED_STATUS  DSM_IV_TR
# 0             4.000000           1                 0.0        1.0
# 1             3.000000           1                 1.0        1.0
# 2             3.000000           1                 0.0        1.0
# 3             4.000000           0                 1.0        1.0
# 4             3.000000           1                 0.0        1.0
# 5             1.000000           1                 0.0        1.0
# 6             2.000000           1                 1.0        1.0
# 7             2.000000           1                 1.0        1.0
# 8             3.218855           1                 0.0        1.0
# 9             1.000000           0                 0.0        1.0

# %%
print(my_dataset['DSM_IV_TR'].value_counts())

# Features in X and resultant classes in y
X = np.array(my_dataset.iloc[:,1:14].values)
y = np.array(my_dataset.iloc[:,14].values)
# Out:
# 0.0    427
# 1.0    252
# 2.0     85
# 3.0     21
# Name: DSM_IV_TR, dtype: int64

# %%
# One-hot-encoding categorical data of HANDEDNESS_CATEGORY
columnTransformer = ColumnTransformer([('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = columnTransformer.fit_transform(X)

# Feature Scaling
sc = StandardScaler()
X = sc.fit_transform(X)

# Splitting the dataset into the Training set and Test set in ratio 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Model Evaluation and predicting classes
# Evaluating seven different models for multiclass classification and recording their accuracies as well as AUC_ROC score for comparing performance. Since ROC uses binary classes, a function is defined which binarizes the labels of predicted and test data.

# %%
model_name = ['Random Forest', 'Logistic Regression', 'kNN', 'SVM_rbf', 'ANN', 'XGBoost']
accuracies = [0]*6
auc_roc = [0]*6

def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)
    return roc_auc_score(y_test, y_pred, average=average)

# %% [markdown]
# ## Random Forest Classifier
# A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. The parameters for the random forest training are defined as follows:
#
# n_estimators: This is the number of trees in the random forest classification. This model uses 45 trees decided after evaluation of a range of values. min_samples_split: This is the minimum number of samples required to split an internal node. The optimal value for the given model was found to be 3. max_depth: The maximum depth of the tree, optimal value chosen is 15 here.
#
# The sub-sample size is always the same as the original input sample size but the samples are drawn with replacement if bootstrap=True (default)

# %%
from sklearn.ensemble import RandomForestClassifier
# Using the best parameters combination after tuning hyper-parameters
rf_classifier = RandomForestClassifier(n_estimators = 45, min_samples_split = 3, max_depth = 15, 
                                       bootstrap = False, random_state = 42)
rf_classifier.fit(X_train, y_train)
y_pred = rf_classifier.predict(X_test)

accuracies[0] = accuracy_score(y_test, y_pred)
auc_roc[0] = multiclass_roc_auc_score(y_test, y_pred)

# %% [markdown]
# ## Logistic Regression classification
# In the multiclass case, this training algorithm uses the one-vs-rest (OvR) scheme if the ‘multi_class’ option is set to ‘ovr’. solver is the algorithm to use in the optimization problem. Maximum number of iterations taken for the solvers to converge are chosen to be 500. It is to be noted that the features (X) are already normalized.

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver = 'saga', multi_class = 'ovr', max_iter = 500)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracies[1] = accuracy_score(y_test, y_pred)
auc_roc[1] = multiclass_roc_auc_score(y_test, y_pred)

# %% [markdown]
# ## K-Nearest Neighbors:
#
# KNN is a simple supervised classification algorithm we can use to assign a class to new data point. Larger K value leads to smoother decision boundary (less complex model). Smaller K leads to more complex model (may lead to overfitting). Testing accuracy penalizes models that are too complex(over fitting) or not complex enough(underfit). We're using an optimal value of k=5.

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 5, weights = 'distance')
knn.fit(X_train, y_train) 
y_pred = knn.predict(X_test)  

accuracies[2] = accuracy_score(y_test, y_pred)
auc_roc[2] = multiclass_roc_auc_score(y_test, y_pred)

# %% [markdown]
# ## Support Vector Machine:
#
# Radial Basis Function (RBF) kernel is applied on the c-support vector classifier. Intuitively, the gamma parameter defines how far the influence of a single training example reaches, with low values meaning ‘far’ and high values meaning ‘close’. The gamma parameters can be seen as the inverse of the radius of influence of samples selected by the model as support vectors.
#
# The C parameter trades off correct classification of training examples against maximization of the decision function’s (One vs All) margin. For larger values of C, a smaller margin will be accepted if the decision function is better at classifying all training points correctly. A lower C will encourage a larger margin, therefore a simpler decision function, at the cost of training accuracy. In other words C behaves as a regularization parameter in the SVM. It is set to the value 0.8 as it gave better scores than default value of 1.

# %%
from sklearn.svm import SVC 
svm_model = SVC(kernel = 'rbf', gamma = 'auto', C=0.8)
svm_model.fit(X_train, y_train) 
y_pred = svm_model.predict(X_test) 

accuracies[3] = accuracy_score(y_test, y_pred)
auc_roc[3] = multiclass_roc_auc_score(y_test, y_pred)

# %% [markdown]
# ## Artificial Neural Network:
#
# In multi-class classification, the neural network has the same number of output nodes as the number of classes. Each output node belongs to a specific class and outputs a score for that class. Scores from the last layer are passed through a softmax layer. Softmax layer converts the score into probability values. At last, data is classified into a corresponding class, that has the highest probability value. The following ANN has 3 hidden layers and with dropout/regularization rate = 0.1
#
# The classifier is built on 'adam' optimizer and categorical cross-entropy for multiclass. Adam is a replacement optimization algorithm for stochastic gradient descent for training deep learning models. The data is cross validated using k-fold (k=10) on shuffled dataset. The ten accuracies are acquired from cross_val_score and their mean is recorded.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

def build_classifier():
    classifier = Sequential()
    # Adding the input layer and the first hidden layer 
    classifier.add(Dense(units = 15, activation = 'relu', input_dim = 17))
    # Adding a hidden layer
    classifier.add(Dense(units = 7, activation = 'relu'))
    classifier.add(Dropout(rate = 0.1))
    # Adding a hidden layer
    classifier.add(Dense(units = 9, activation = 'relu'))
    classifier.add(Dropout(rate = 0.1))
    # Adding a hidden layer
    classifier.add(Dense(units = 7, activation = 'relu'))
    classifier.add(Dropout(rate = 0.1))
    # Adding the output layer
    classifier.add(Dense(units = 4, activation = 'softmax'))
    # Compiling the ANN
    classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return classifier

# Encoding the classes in y
y_binary = to_categorical(y)

cv = KFold(n_splits=10, random_state=42, shuffle=True)
classifier = KerasClassifier(build_fn = build_classifier, batch_size=25, epochs=200)
acc_cv = cross_val_score(estimator = classifier, X = X, y = y_binary, cv = cv)

accuracies[4] = acc_cv.mean()
auc_roc[4] = ' '
# Out:
# WARNING:tensorflow:From C:\Users\HOME\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/200
# 706/706 [==============================] - 1s 2ms/step - loss: 1.3972 - accuracy: 0.4533
# Epoch 2/200
# 706/706 [==============================] - 0s 73us/step - loss: 1.3633 - accuracy: 0.5397
# Epoch 3/200
# 706/706 [==============================] - 0s 72us/step - loss: 1.3282 - accuracy: 0.5397
# Epoch 4/200
# 706/706 [==============================] - 0s 89us/step - loss: 1.2837 - accuracy: 0.5411
# Epoch 5/200
# 706/706 [==============================] - 0s 83us/step - loss: 1.2207 - accuracy: 0.5397
# Epoch 6/200
# 706/706 [==============================] - 0s 83us/step - loss: 1.1495 - accuracy: 0.5397
# Epoch 7/200
# 706/706 [==============================] - 0s 75us/step - loss: 1.0980 - accuracy: 0.5397
# Epoch 8/200
# 706/706 [==============================] - 0s 53us/step - loss: 1.0661 - accuracy: 0.5397
# Epoch 9/200
# 706/706 [==============================] - 0s 69us/step - loss: 1.0255 - accuracy: 0.5439
# Epoch 10/200
# 706/706 [==============================] - 0s 83us/step - loss: 1.0010 - accuracy: 0.5538
# Epoch 11/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.9529 - accuracy: 0.5567
# Epoch 12/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.9281 - accuracy: 0.6062
# Epoch 13/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.9258 - accuracy: 0.6898
# Epoch 14/200
# 706/706 [==============================] - 0s 65us/step - loss: 0.8804 - accuracy: 0.6969
# Epoch 15/200
# 706/706 [==============================] - 0s 73us/step - loss: 0.8551 - accuracy: 0.7181
# Epoch 16/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.8279 - accuracy: 0.7422
# Epoch 17/200
# 706/706 [==============================] - 0s 64us/step - loss: 0.8397 - accuracy: 0.7266
# Epoch 18/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.8287 - accuracy: 0.7295
# Epoch 19/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.7530 - accuracy: 0.7620
# Epoch 20/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.7536 - accuracy: 0.7578
# Epoch 21/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.7375 - accuracy: 0.7705
# Epoch 22/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.7141 - accuracy: 0.7734
# Epoch 23/200
# 706/706 [==============================] - 0s 59us/step - loss: 0.7016 - accuracy: 0.7776
# Epoch 24/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.7032 - accuracy: 0.7875
# Epoch 25/200
# 706/706 [==============================] - 0s 116us/step - loss: 0.6772 - accuracy: 0.8017
# Epoch 26/200
# 706/706 [==============================] - 0s 106us/step - loss: 0.6987 - accuracy: 0.7776
# Epoch 27/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.6707 - accuracy: 0.7946
# Epoch 28/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.6603 - accuracy: 0.7904
# Epoch 29/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.6406 - accuracy: 0.8074
# Epoch 30/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.6615 - accuracy: 0.7904
# Epoch 31/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.6393 - accuracy: 0.8074
# Epoch 32/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.6247 - accuracy: 0.8017
# Epoch 33/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.6221 - accuracy: 0.8116
# Epoch 34/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.6053 - accuracy: 0.8102
# Epoch 35/200
# 706/706 [==============================] - 0s 109us/step - loss: 0.5907 - accuracy: 0.8173
# Epoch 36/200
# 706/706 [==============================] - 0s 113us/step - loss: 0.6121 - accuracy: 0.8017
# Epoch 37/200
# 706/706 [==============================] - 0s 107us/step - loss: 0.6111 - accuracy: 0.8144
# Epoch 38/200
# 706/706 [==============================] - 0s 117us/step - loss: 0.6135 - accuracy: 0.8130
# Epoch 39/200
# 706/706 [==============================] - 0s 102us/step - loss: 0.5915 - accuracy: 0.8116
# Epoch 40/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.5928 - accuracy: 0.8130
# Epoch 41/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.5942 - accuracy: 0.8159
# Epoch 42/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5867 - accuracy: 0.8173
# Epoch 43/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.5919 - accuracy: 0.8159
# Epoch 44/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.5830 - accuracy: 0.8159
# Epoch 45/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.5662 - accuracy: 0.8159
# Epoch 46/200
# 706/706 [==============================] - 0s 103us/step - loss: 0.5760 - accuracy: 0.8173
# Epoch 47/200
# 706/706 [==============================] - 0s 106us/step - loss: 0.5721 - accuracy: 0.8272
# Epoch 48/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.5563 - accuracy: 0.8187
# Epoch 49/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.5707 - accuracy: 0.8201
# Epoch 50/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.5651 - accuracy: 0.8074
# Epoch 51/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.5624 - accuracy: 0.8258
# Epoch 52/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.5567 - accuracy: 0.8201
# Epoch 53/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.5564 - accuracy: 0.8201
# Epoch 54/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5261 - accuracy: 0.8258
# Epoch 55/200
# 706/706 [==============================] - 0s 84us/step - loss: 0.5528 - accuracy: 0.8187
# Epoch 56/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.5698 - accuracy: 0.8144
# Epoch 57/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.5636 - accuracy: 0.8159
# Epoch 58/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.5457 - accuracy: 0.8229
# Epoch 59/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.5529 - accuracy: 0.8159
# Epoch 60/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5421 - accuracy: 0.8215
# Epoch 61/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.5608 - accuracy: 0.8116
# Epoch 62/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.5437 - accuracy: 0.8229
# Epoch 63/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.5394 - accuracy: 0.8173
# Epoch 64/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5375 - accuracy: 0.8244
# Epoch 65/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.5422 - accuracy: 0.8215
# Epoch 66/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5479 - accuracy: 0.8229
# Epoch 67/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.5340 - accuracy: 0.8215
# Epoch 68/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.5276 - accuracy: 0.8229
# Epoch 69/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5301 - accuracy: 0.8159
# Epoch 70/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.5292 - accuracy: 0.8201
# Epoch 71/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.5260 - accuracy: 0.8187
# Epoch 72/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.5290 - accuracy: 0.8258
# Epoch 73/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.5223 - accuracy: 0.8215
# Epoch 74/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5068 - accuracy: 0.8272
# Epoch 75/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5280 - accuracy: 0.8116
# Epoch 76/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5159 - accuracy: 0.8258
# Epoch 77/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.5023 - accuracy: 0.8314
# Epoch 78/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.4927 - accuracy: 0.8258
# Epoch 79/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.5241 - accuracy: 0.8272
# Epoch 80/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.5098 - accuracy: 0.8286
# Epoch 81/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.5080 - accuracy: 0.8300
# Epoch 82/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.5026 - accuracy: 0.8300
# Epoch 83/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.4838 - accuracy: 0.8357
# Epoch 84/200
# 706/706 [==============================] - 0s 68us/step - loss: 0.4883 - accuracy: 0.8314
# Epoch 85/200
# 706/706 [==============================] - 0s 51us/step - loss: 0.4980 - accuracy: 0.8286
# Epoch 86/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.4889 - accuracy: 0.8371
# Epoch 87/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.4899 - accuracy: 0.8300
# Epoch 88/200
# 706/706 [==============================] - 0s 60us/step - loss: 0.5077 - accuracy: 0.8258
# Epoch 89/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.4719 - accuracy: 0.8329
# Epoch 90/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.4864 - accuracy: 0.8300
# Epoch 91/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.4847 - accuracy: 0.8300
# Epoch 92/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.4661 - accuracy: 0.8414
# Epoch 93/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.4934 - accuracy: 0.8329
# Epoch 94/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.4955 - accuracy: 0.8371
# Epoch 95/200
# 706/706 [==============================] - 0s 62us/step - loss: 0.4996 - accuracy: 0.8300
# Epoch 96/200
# 706/706 [==============================] - 0s 57us/step - loss: 0.4683 - accuracy: 0.8343
# Epoch 97/200
# 706/706 [==============================] - 0s 74us/step - loss: 0.4497 - accuracy: 0.8357
# Epoch 98/200
# 706/706 [==============================] - 0s 84us/step - loss: 0.4714 - accuracy: 0.8272
# Epoch 99/200
# 706/706 [==============================] - 0s 73us/step - loss: 0.4750 - accuracy: 0.8385
# Epoch 100/200
# 706/706 [==============================] - 0s 70us/step - loss: 0.4881 - accuracy: 0.8329
# Epoch 101/200
# 706/706 [==============================] - 0s 73us/step - loss: 0.4626 - accuracy: 0.8286
# Epoch 102/200
# 706/706 [==============================] - 0s 56us/step - loss: 0.4716 - accuracy: 0.8329
# Epoch 103/200
# 706/706 [==============================] - 0s 74us/step - loss: 0.4753 - accuracy: 0.8286
# Epoch 104/200
# 706/706 [==============================] - 0s 70us/step - loss: 0.4619 - accuracy: 0.8343
# Epoch 105/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.4664 - accuracy: 0.8314
# Epoch 106/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.4622 - accuracy: 0.8272
# Epoch 107/200
# 706/706 [==============================] - 0s 66us/step - loss: 0.4604 - accuracy: 0.8329
# Epoch 108/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4849 - accuracy: 0.8357
# Epoch 109/200
# 706/706 [==============================] - 0s 64us/step - loss: 0.4693 - accuracy: 0.8272
# Epoch 110/200
# 706/706 [==============================] - 0s 65us/step - loss: 0.4602 - accuracy: 0.8272
# Epoch 111/200
# 706/706 [==============================] - 0s 80us/step - loss: 0.4663 - accuracy: 0.8357
# Epoch 112/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.4484 - accuracy: 0.8329
# Epoch 113/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4629 - accuracy: 0.8371
# Epoch 114/200
# 706/706 [==============================] - 0s 66us/step - loss: 0.4362 - accuracy: 0.8343
# Epoch 115/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.4447 - accuracy: 0.8371
# Epoch 116/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.4752 - accuracy: 0.8314
# Epoch 117/200
# 706/706 [==============================] - 0s 54us/step - loss: 0.4704 - accuracy: 0.8286
# Epoch 118/200
# 706/706 [==============================] - 0s 78us/step - loss: 0.4442 - accuracy: 0.8371
# Epoch 119/200
# 706/706 [==============================] - 0s 72us/step - loss: 0.4408 - accuracy: 0.8399
# Epoch 120/200
# 706/706 [==============================] - 0s 71us/step - loss: 0.4495 - accuracy: 0.8371
# Epoch 121/200
# 706/706 [==============================] - 0s 90us/step - loss: 0.4338 - accuracy: 0.8399
# Epoch 122/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.4326 - accuracy: 0.8357
# Epoch 123/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.4560 - accuracy: 0.8414
# Epoch 124/200
# 706/706 [==============================] - 0s 73us/step - loss: 0.4413 - accuracy: 0.8399
# Epoch 125/200
# 706/706 [==============================] - ETA: 0s - loss: 0.5992 - accuracy: 0.76 - 0s 73us/step - loss: 0.4298 - accuracy: 0.8357
# Epoch 126/200
# 706/706 [==============================] - 0s 61us/step - loss: 0.4512 - accuracy: 0.8357
# Epoch 127/200
# 706/706 [==============================] - 0s 79us/step - loss: 0.4181 - accuracy: 0.8428
# Epoch 128/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4486 - accuracy: 0.8343
# Epoch 129/200
# 706/706 [==============================] - 0s 67us/step - loss: 0.4293 - accuracy: 0.8371
# Epoch 130/200
# 706/706 [==============================] - 0s 94us/step - loss: 0.4463 - accuracy: 0.8314
# Epoch 131/200
# 706/706 [==============================] - 0s 66us/step - loss: 0.4230 - accuracy: 0.8371
# Epoch 132/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.4554 - accuracy: 0.8286
# Epoch 133/200
# 706/706 [==============================] - 0s 70us/step - loss: 0.4452 - accuracy: 0.8286
# Epoch 134/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4555 - accuracy: 0.8371
# Epoch 135/200
# 706/706 [==============================] - 0s 64us/step - loss: 0.4141 - accuracy: 0.8456
# Epoch 136/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4458 - accuracy: 0.8414
# Epoch 137/200
# 706/706 [==============================] - 0s 69us/step - loss: 0.4372 - accuracy: 0.8371
# Epoch 138/200
# 706/706 [==============================] - 0s 91us/step - loss: 0.4387 - accuracy: 0.8428
# Epoch 139/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4305 - accuracy: 0.8385
# Epoch 140/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4288 - accuracy: 0.8357
# Epoch 141/200
# 706/706 [==============================] - 0s 64us/step - loss: 0.4382 - accuracy: 0.8314
# Epoch 142/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4416 - accuracy: 0.8371
# Epoch 143/200
# 706/706 [==============================] - 0s 63us/step - loss: 0.4487 - accuracy: 0.8300
# Epoch 144/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.4056 - accuracy: 0.8428
# Epoch 145/200
# 706/706 [==============================] - 0s 77us/step - loss: 0.4177 - accuracy: 0.8357
# Epoch 146/200
# 706/706 [==============================] - 0s 63us/step - loss: 0.4280 - accuracy: 0.8329
# Epoch 147/200
# 706/706 [==============================] - 0s 120us/step - loss: 0.4119 - accuracy: 0.8499
# Epoch 148/200
# 706/706 [==============================] - 0s 114us/step - loss: 0.4418 - accuracy: 0.8343
# Epoch 149/200
# 706/706 [==============================] - 0s 109us/step - loss: 0.4230 - accuracy: 0.8385
# Epoch 150/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.4095 - accuracy: 0.8371
# Epoch 151/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.4176 - accuracy: 0.8371
# Epoch 152/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4463 - accuracy: 0.8258
# Epoch 153/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4124 - accuracy: 0.8329
# Epoch 154/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4438 - accuracy: 0.8272
# Epoch 155/200
# 706/706 [==============================] - 0s 114us/step - loss: 0.4169 - accuracy: 0.8470
# Epoch 156/200
# 706/706 [==============================] - 0s 105us/step - loss: 0.4257 - accuracy: 0.8329
# Epoch 157/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.4277 - accuracy: 0.8399
# Epoch 158/200
# 706/706 [==============================] - 0s 101us/step - loss: 0.4162 - accuracy: 0.8428
# Epoch 159/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.4429 - accuracy: 0.8272
# Epoch 160/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.4202 - accuracy: 0.8371
# Epoch 161/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.4242 - accuracy: 0.8385
# Epoch 162/200
# 706/706 [==============================] - 0s 102us/step - loss: 0.4060 - accuracy: 0.8371
# Epoch 163/200
# 706/706 [==============================] - 0s 102us/step - loss: 0.4165 - accuracy: 0.8371
# Epoch 164/200
# 706/706 [==============================] - 0s 102us/step - loss: 0.4108 - accuracy: 0.8414
# Epoch 165/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.4116 - accuracy: 0.8385
# Epoch 166/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.4072 - accuracy: 0.8428
# Epoch 167/200
# 706/706 [==============================] - 0s 95us/step - loss: 0.4385 - accuracy: 0.8329
# Epoch 168/200
# 706/706 [==============================] - 0s 102us/step - loss: 0.4011 - accuracy: 0.8371
# Epoch 169/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.4117 - accuracy: 0.8414
# Epoch 170/200
# 706/706 [==============================] - 0s 106us/step - loss: 0.4102 - accuracy: 0.8371
# Epoch 171/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.4004 - accuracy: 0.8513
# Epoch 172/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.3959 - accuracy: 0.8442
# Epoch 173/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.4126 - accuracy: 0.8414
# Epoch 174/200
# 706/706 [==============================] - 0s 95us/step - loss: 0.3921 - accuracy: 0.8399
# Epoch 175/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.4028 - accuracy: 0.8300
# Epoch 176/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4020 - accuracy: 0.8385
# Epoch 177/200
# 706/706 [==============================] - 0s 105us/step - loss: 0.4015 - accuracy: 0.8442
# Epoch 178/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.4050 - accuracy: 0.8499
# Epoch 179/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4040 - accuracy: 0.8428
# Epoch 180/200
# 706/706 [==============================] - 0s 119us/step - loss: 0.4046 - accuracy: 0.8343
# Epoch 181/200
# 706/706 [==============================] - 0s 105us/step - loss: 0.4202 - accuracy: 0.8414
# Epoch 182/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.4100 - accuracy: 0.8456
# Epoch 183/200
# 706/706 [==============================] - 0s 90us/step - loss: 0.4158 - accuracy: 0.8314
# Epoch 184/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.4058 - accuracy: 0.8314
# Epoch 185/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.4035 - accuracy: 0.8428
# Epoch 186/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.4043 - accuracy: 0.8428
# Epoch 187/200
# 706/706 [==============================] - 0s 73us/step - loss: 0.3932 - accuracy: 0.8456
# Epoch 188/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.4031 - accuracy: 0.8470
# Epoch 189/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.3976 - accuracy: 0.8399
# Epoch 190/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.3903 - accuracy: 0.8513
# Epoch 191/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.3899 - accuracy: 0.8343
# Epoch 192/200
# 706/706 [==============================] - 0s 74us/step - loss: 0.4056 - accuracy: 0.8343
# Epoch 193/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.3988 - accuracy: 0.8527
# Epoch 194/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.3930 - accuracy: 0.8414
# Epoch 195/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.3923 - accuracy: 0.8499
# Epoch 196/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.3919 - accuracy: 0.8428
# Epoch 197/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.3979 - accuracy: 0.8456
# Epoch 198/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.3890 - accuracy: 0.8414
# Epoch 199/200
# 706/706 [==============================] - 0s 74us/step - loss: 0.3899 - accuracy: 0.8499
# Epoch 200/200
# 706/706 [==============================] - 0s 74us/step - loss: 0.3901 - accuracy: 0.8414
# 79/79 [==============================] - 0s 2ms/step
# Epoch 1/200
# 706/706 [==============================] - 0s 486us/step - loss: 1.6577 - accuracy: 0.1997
# Epoch 2/200
# 706/706 [==============================] - 0s 82us/step - loss: 1.4348 - accuracy: 0.3952
# Epoch 3/200
# 706/706 [==============================] - 0s 77us/step - loss: 1.3363 - accuracy: 0.5042
# Epoch 4/200
# 706/706 [==============================] - 0s 83us/step - loss: 1.2746 - accuracy: 0.5552
# Epoch 5/200
# 706/706 [==============================] - 0s 88us/step - loss: 1.2333 - accuracy: 0.5722
# Epoch 6/200
# 706/706 [==============================] - 0s 86us/step - loss: 1.1754 - accuracy: 0.5907
# Epoch 7/200
# 706/706 [==============================] - 0s 90us/step - loss: 1.1275 - accuracy: 0.6147
# Epoch 8/200
# 706/706 [==============================] - 0s 93us/step - loss: 1.0846 - accuracy: 0.6374
# Epoch 9/200
# 706/706 [==============================] - 0s 81us/step - loss: 1.0676 - accuracy: 0.6204
# Epoch 10/200
# 706/706 [==============================] - 0s 90us/step - loss: 1.0279 - accuracy: 0.6374
# Epoch 11/200
# 706/706 [==============================] - 0s 91us/step - loss: 0.9995 - accuracy: 0.6416
# Epoch 12/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.9836 - accuracy: 0.6530
# Epoch 13/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.9763 - accuracy: 0.6360
# Epoch 14/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.9483 - accuracy: 0.6572
# Epoch 15/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.9208 - accuracy: 0.6714
# Epoch 16/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.9084 - accuracy: 0.6728
# Epoch 17/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.9278 - accuracy: 0.6558
# Epoch 18/200
# 706/706 [==============================] - 0s 113us/step - loss: 0.9107 - accuracy: 0.6657
# Epoch 19/200
# 706/706 [==============================] - 0s 106us/step - loss: 0.8945 - accuracy: 0.6686
# Epoch 20/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.8827 - accuracy: 0.6870
# Epoch 21/200
# 706/706 [==============================] - 0s 108us/step - loss: 0.8798 - accuracy: 0.6813
# Epoch 22/200
# 706/706 [==============================] - 0s 107us/step - loss: 0.8509 - accuracy: 0.6841
# Epoch 23/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.8527 - accuracy: 0.6870
# Epoch 24/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.8369 - accuracy: 0.6771
# Epoch 25/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.8392 - accuracy: 0.7011
# Epoch 26/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.8352 - accuracy: 0.6969
# Epoch 27/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.7846 - accuracy: 0.7238
# Epoch 28/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.7714 - accuracy: 0.7266
# Epoch 29/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.7840 - accuracy: 0.7252
# Epoch 30/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.7546 - accuracy: 0.7167
# Epoch 31/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.7696 - accuracy: 0.7266
# Epoch 32/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.7367 - accuracy: 0.7422
# Epoch 33/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.7022 - accuracy: 0.7592
# Epoch 34/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.6891 - accuracy: 0.7507
# Epoch 35/200
# 706/706 [==============================] - 0s 84us/step - loss: 0.6929 - accuracy: 0.7436
# Epoch 36/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.6658 - accuracy: 0.7564
# Epoch 37/200
# 706/706 [==============================] - ETA: 0s - loss: 0.6540 - accuracy: 0.77 - 0s 83us/step - loss: 0.6536 - accuracy: 0.7790
# Epoch 38/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.6490 - accuracy: 0.7620
# Epoch 39/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.6370 - accuracy: 0.7734
# Epoch 40/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.6111 - accuracy: 0.7861
# Epoch 41/200
# 706/706 [==============================] - 0s 79us/step - loss: 0.6204 - accuracy: 0.7904
# Epoch 42/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.6262 - accuracy: 0.7805
# Epoch 43/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.5925 - accuracy: 0.8031
# Epoch 44/200
# 706/706 [==============================] - 0s 90us/step - loss: 0.6103 - accuracy: 0.7890
# Epoch 45/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.5859 - accuracy: 0.7904
# Epoch 46/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.6071 - accuracy: 0.7776
# Epoch 47/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.5747 - accuracy: 0.8017
# Epoch 48/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.5893 - accuracy: 0.8031
# Epoch 49/200
# 706/706 [==============================] - ETA: 0s - loss: 0.5684 - accuracy: 0.80 - 0s 84us/step - loss: 0.5739 - accuracy: 0.7989
# Epoch 50/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.5573 - accuracy: 0.8130
# Epoch 51/200
# 706/706 [==============================] - 0s 90us/step - loss: 0.5618 - accuracy: 0.7946
# Epoch 52/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.5420 - accuracy: 0.8130
# Epoch 53/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.5494 - accuracy: 0.8088
# Epoch 54/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.5396 - accuracy: 0.8187
# Epoch 55/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.5496 - accuracy: 0.8074
# Epoch 56/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.5646 - accuracy: 0.8088
# Epoch 57/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.5558 - accuracy: 0.8102
# Epoch 58/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.5374 - accuracy: 0.8130
# Epoch 59/200
# 706/706 [==============================] - 0s 119us/step - loss: 0.5404 - accuracy: 0.8244
# Epoch 60/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.5304 - accuracy: 0.8300
# Epoch 61/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.5215 - accuracy: 0.8244
# Epoch 62/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.5296 - accuracy: 0.8258
# Epoch 63/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.5208 - accuracy: 0.8314
# Epoch 64/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.5200 - accuracy: 0.8144
# Epoch 65/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.5176 - accuracy: 0.8159
# Epoch 66/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.5120 - accuracy: 0.8130
# Epoch 67/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.5307 - accuracy: 0.8088
# Epoch 68/200
# 706/706 [==============================] - 0s 84us/step - loss: 0.5096 - accuracy: 0.8300
# Epoch 69/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.5434 - accuracy: 0.8102
# Epoch 70/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.5039 - accuracy: 0.8173
# Epoch 71/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.5097 - accuracy: 0.8399
# Epoch 72/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4910 - accuracy: 0.8414
# Epoch 73/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.5110 - accuracy: 0.8229
# Epoch 74/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.5103 - accuracy: 0.8286
# Epoch 75/200
# 706/706 [==============================] - 0s 112us/step - loss: 0.4625 - accuracy: 0.8371
# Epoch 76/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4993 - accuracy: 0.8286
# Epoch 77/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4962 - accuracy: 0.8399
# Epoch 78/200
# 706/706 [==============================] - 0s 119us/step - loss: 0.4781 - accuracy: 0.8314
# Epoch 79/200
# 706/706 [==============================] - 0s 90us/step - loss: 0.4909 - accuracy: 0.8314
# Epoch 80/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4902 - accuracy: 0.8272
# Epoch 81/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4961 - accuracy: 0.8428
# Epoch 82/200
# 706/706 [==============================] - 0s 77us/step - loss: 0.4961 - accuracy: 0.8314
# Epoch 83/200
# 706/706 [==============================] - 0s 90us/step - loss: 0.5053 - accuracy: 0.8215
# Epoch 84/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.4579 - accuracy: 0.8499
# Epoch 85/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4692 - accuracy: 0.8357
# Epoch 86/200
# 706/706 [==============================] - 0s 84us/step - loss: 0.4881 - accuracy: 0.8329
# Epoch 87/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.4789 - accuracy: 0.8385
# Epoch 88/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4700 - accuracy: 0.8371
# Epoch 89/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4662 - accuracy: 0.8314
# Epoch 90/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4591 - accuracy: 0.8385
# Epoch 91/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4633 - accuracy: 0.8314
# Epoch 92/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.4917 - accuracy: 0.8258
# Epoch 93/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4654 - accuracy: 0.8484
# Epoch 94/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4880 - accuracy: 0.8286
# Epoch 95/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4535 - accuracy: 0.8385
# Epoch 96/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4873 - accuracy: 0.8286
# Epoch 97/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4813 - accuracy: 0.8314
# Epoch 98/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4617 - accuracy: 0.8513
# Epoch 99/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4435 - accuracy: 0.8513
# Epoch 100/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4618 - accuracy: 0.8442
# Epoch 101/200
# 706/706 [==============================] - 0s 101us/step - loss: 0.4570 - accuracy: 0.8470
# Epoch 102/200
# 706/706 [==============================] - 0s 107us/step - loss: 0.4369 - accuracy: 0.8513
# Epoch 103/200
# 706/706 [==============================] - 0s 95us/step - loss: 0.4482 - accuracy: 0.8456
# Epoch 104/200
# 706/706 [==============================] - 0s 101us/step - loss: 0.4488 - accuracy: 0.8484
# Epoch 105/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4755 - accuracy: 0.8470
# Epoch 106/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4687 - accuracy: 0.8442
# Epoch 107/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4586 - accuracy: 0.8499
# Epoch 108/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.4536 - accuracy: 0.8541
# Epoch 109/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4485 - accuracy: 0.8343
# Epoch 110/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4207 - accuracy: 0.8541
# Epoch 111/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.4462 - accuracy: 0.8414
# Epoch 112/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.4694 - accuracy: 0.8456
# Epoch 113/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.4506 - accuracy: 0.8484
# Epoch 114/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4535 - accuracy: 0.8428
# Epoch 115/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4287 - accuracy: 0.8527
# Epoch 116/200
# 706/706 [==============================] - 0s 84us/step - loss: 0.4430 - accuracy: 0.8484
# Epoch 117/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.4211 - accuracy: 0.8555
# Epoch 118/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.4203 - accuracy: 0.8499
# Epoch 119/200
# 706/706 [==============================] - ETA: 0s - loss: 0.4181 - accuracy: 0.85 - 0s 87us/step - loss: 0.4207 - accuracy: 0.8584
# Epoch 120/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.4560 - accuracy: 0.8343
# Epoch 121/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4382 - accuracy: 0.8569
# Epoch 122/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4327 - accuracy: 0.8527
# Epoch 123/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4423 - accuracy: 0.8626
# Epoch 124/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.4391 - accuracy: 0.8513
# Epoch 125/200
# 706/706 [==============================] - ETA: 0s - loss: 0.4394 - accuracy: 0.85 - 0s 80us/step - loss: 0.4371 - accuracy: 0.8598
# Epoch 126/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.4300 - accuracy: 0.8456
# Epoch 127/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.4204 - accuracy: 0.8598
# Epoch 128/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4190 - accuracy: 0.8584
# Epoch 129/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4321 - accuracy: 0.8484
# Epoch 130/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4225 - accuracy: 0.8626
# Epoch 131/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.4294 - accuracy: 0.8527
# Epoch 132/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.4294 - accuracy: 0.8555
# Epoch 133/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.4075 - accuracy: 0.8555
# Epoch 134/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.4477 - accuracy: 0.8527
# Epoch 135/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4416 - accuracy: 0.8470
# Epoch 136/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.3976 - accuracy: 0.8711
# Epoch 137/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4429 - accuracy: 0.8555
# Epoch 138/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4206 - accuracy: 0.8598
# Epoch 139/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4034 - accuracy: 0.8683
# Epoch 140/200
# 706/706 [==============================] - 0s 81us/step - loss: 0.4098 - accuracy: 0.8754
# Epoch 141/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4114 - accuracy: 0.8598
# Epoch 142/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4465 - accuracy: 0.8428
# Epoch 143/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4122 - accuracy: 0.8697
# Epoch 144/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4303 - accuracy: 0.8499
# Epoch 145/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.4264 - accuracy: 0.8584
# Epoch 146/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.4130 - accuracy: 0.8527
# Epoch 147/200
# 706/706 [==============================] - 0s 78us/step - loss: 0.3986 - accuracy: 0.8654
# Epoch 148/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4209 - accuracy: 0.8555
# Epoch 149/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.4148 - accuracy: 0.8669
# Epoch 150/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.4169 - accuracy: 0.8612
# Epoch 151/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4009 - accuracy: 0.8711
# Epoch 152/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4066 - accuracy: 0.8584
# Epoch 153/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4290 - accuracy: 0.8640
# Epoch 154/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.4058 - accuracy: 0.8555
# Epoch 155/200
# 706/706 [==============================] - 0s 80us/step - loss: 0.3980 - accuracy: 0.8626
# Epoch 156/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4010 - accuracy: 0.8569
# Epoch 157/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4095 - accuracy: 0.8640
# Epoch 158/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.4325 - accuracy: 0.8513
# Epoch 159/200
# 706/706 [==============================] - 0s 105us/step - loss: 0.4254 - accuracy: 0.8555
# Epoch 160/200
# 706/706 [==============================] - 0s 119us/step - loss: 0.4115 - accuracy: 0.8612
# Epoch 161/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.3638 - accuracy: 0.8796
# Epoch 162/200
# 706/706 [==============================] - 0s 106us/step - loss: 0.4069 - accuracy: 0.8598
# Epoch 163/200
# 706/706 [==============================] - 0s 107us/step - loss: 0.3794 - accuracy: 0.8739
# Epoch 164/200
# 706/706 [==============================] - 0s 101us/step - loss: 0.3937 - accuracy: 0.8711
# Epoch 165/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.3912 - accuracy: 0.8669
# Epoch 166/200
# 706/706 [==============================] - 0s 94us/step - loss: 0.3923 - accuracy: 0.8654
# Epoch 167/200
# 706/706 [==============================] - 0s 103us/step - loss: 0.4225 - accuracy: 0.8654
# Epoch 168/200
# 706/706 [==============================] - 0s 110us/step - loss: 0.3978 - accuracy: 0.8683
# Epoch 169/200
# 706/706 [==============================] - 0s 110us/step - loss: 0.3867 - accuracy: 0.8669
# Epoch 170/200
# 706/706 [==============================] - 0s 105us/step - loss: 0.4048 - accuracy: 0.8654
# Epoch 171/200
# 706/706 [==============================] - 0s 110us/step - loss: 0.3970 - accuracy: 0.8669
# Epoch 172/200
# 706/706 [==============================] - 0s 101us/step - loss: 0.4147 - accuracy: 0.8541
# Epoch 173/200
# 706/706 [==============================] - 0s 106us/step - loss: 0.3954 - accuracy: 0.8598
# Epoch 174/200
# 706/706 [==============================] - 0s 106us/step - loss: 0.3832 - accuracy: 0.8768
# Epoch 175/200
# 706/706 [==============================] - 0s 102us/step - loss: 0.3948 - accuracy: 0.8683
# Epoch 176/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.4217 - accuracy: 0.8640
# Epoch 177/200
# 706/706 [==============================] - 0s 107us/step - loss: 0.4182 - accuracy: 0.8612
# Epoch 178/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.3819 - accuracy: 0.8711
# Epoch 179/200
# 706/706 [==============================] - 0s 104us/step - loss: 0.3723 - accuracy: 0.8669
# Epoch 180/200
# 706/706 [==============================] - 0s 102us/step - loss: 0.4060 - accuracy: 0.8626
# Epoch 181/200
# 706/706 [==============================] - 0s 97us/step - loss: 0.3909 - accuracy: 0.8683
# Epoch 182/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.3777 - accuracy: 0.8612
# Epoch 183/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.3814 - accuracy: 0.8640
# Epoch 184/200
# 706/706 [==============================] - 0s 104us/step - loss: 0.4216 - accuracy: 0.8626
# Epoch 185/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.3984 - accuracy: 0.8640
# Epoch 186/200
# 706/706 [==============================] - ETA: 0s - loss: 0.4078 - accuracy: 0.86 - 0s 103us/step - loss: 0.4040 - accuracy: 0.8669
# Epoch 187/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.3791 - accuracy: 0.8796
# Epoch 188/200
# 706/706 [==============================] - 0s 90us/step - loss: 0.3826 - accuracy: 0.8725
# Epoch 189/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.3866 - accuracy: 0.8725
# Epoch 190/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.3704 - accuracy: 0.8782
# Epoch 191/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.3878 - accuracy: 0.8683
# Epoch 192/200
# 706/706 [==============================] - 0s 94us/step - loss: 0.3693 - accuracy: 0.8725
# Epoch 193/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.3804 - accuracy: 0.8711
# Epoch 194/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.3976 - accuracy: 0.8584
# Epoch 195/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.3720 - accuracy: 0.8796
# Epoch 196/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.3639 - accuracy: 0.8867
# Epoch 197/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.3700 - accuracy: 0.8725
# Epoch 198/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.3880 - accuracy: 0.8654
# Epoch 199/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.3890 - accuracy: 0.8697
# Epoch 200/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.3999 - accuracy: 0.8612
# 79/79 [==============================] - 0s 974us/step
# Epoch 1/200
# 706/706 [==============================] - 0s 530us/step - loss: 1.3989 - accuracy: 0.2932
# Epoch 2/200
# 706/706 [==============================] - 0s 80us/step - loss: 1.3267 - accuracy: 0.4802
# Epoch 3/200
# 706/706 [==============================] - 0s 82us/step - loss: 1.2743 - accuracy: 0.4915
# Epoch 4/200
# 706/706 [==============================] - 0s 83us/step - loss: 1.2420 - accuracy: 0.5241
# Epoch 5/200
# 706/706 [==============================] - 0s 88us/step - loss: 1.2028 - accuracy: 0.5652
# Epoch 6/200
# 706/706 [==============================] - 0s 86us/step - loss: 1.1516 - accuracy: 0.6176
# Epoch 7/200
# 706/706 [==============================] - 0s 90us/step - loss: 1.1085 - accuracy: 0.6643
# Epoch 8/200
# 706/706 [==============================] - 0s 88us/step - loss: 1.0666 - accuracy: 0.6459
# Epoch 9/200
# 706/706 [==============================] - 0s 83us/step - loss: 1.0160 - accuracy: 0.6756
# Epoch 10/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.9683 - accuracy: 0.6799
# Epoch 11/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.9334 - accuracy: 0.6813
# Epoch 12/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.9092 - accuracy: 0.6983
# Epoch 13/200
# 706/706 [==============================] - 0s 78us/step - loss: 0.8834 - accuracy: 0.7011
# Epoch 14/200
# 706/706 [==============================] - 0s 84us/step - loss: 0.8586 - accuracy: 0.7082
# Epoch 15/200
# 706/706 [==============================] - 0s 82us/step - loss: 0.8384 - accuracy: 0.7153
# Epoch 16/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.8076 - accuracy: 0.7365
# Epoch 17/200
# 706/706 [==============================] - 0s 105us/step - loss: 0.8128 - accuracy: 0.7167
# Epoch 18/200
# 706/706 [==============================] - 0s 83us/step - loss: 0.7941 - accuracy: 0.7521
# Epoch 19/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.7613 - accuracy: 0.7493
# Epoch 20/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.7330 - accuracy: 0.7592
# Epoch 21/200
# 706/706 [==============================] - 0s 84us/step - loss: 0.7178 - accuracy: 0.7564
# Epoch 22/200
# 706/706 [==============================] - 0s 76us/step - loss: 0.7047 - accuracy: 0.7790
# Epoch 23/200
# 706/706 [==============================] - 0s 85us/step - loss: 0.6916 - accuracy: 0.7691
# Epoch 24/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.7032 - accuracy: 0.7705
# Epoch 25/200
# 706/706 [==============================] - 0s 117us/step - loss: 0.6701 - accuracy: 0.7805
# Epoch 26/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.6573 - accuracy: 0.7819
# Epoch 27/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.6473 - accuracy: 0.7861
# Epoch 28/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.6631 - accuracy: 0.7875
# Epoch 29/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.6222 - accuracy: 0.8003
# Epoch 30/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.6498 - accuracy: 0.7960
# Epoch 31/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.6285 - accuracy: 0.7932
# Epoch 32/200
# 706/706 [==============================] - 0s 91us/step - loss: 0.6183 - accuracy: 0.8045
# Epoch 33/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.6010 - accuracy: 0.8059
# Epoch 34/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.6014 - accuracy: 0.8074
# Epoch 35/200
# 706/706 [==============================] - 0s 91us/step - loss: 0.6083 - accuracy: 0.8017
# Epoch 36/200
# 706/706 [==============================] - 0s 78us/step - loss: 0.5966 - accuracy: 0.8031
# Epoch 37/200
# 706/706 [==============================] - 0s 106us/step - loss: 0.5806 - accuracy: 0.8159
# Epoch 38/200
# 706/706 [==============================] - 0s 89us/step - loss: 0.5691 - accuracy: 0.8116
# Epoch 39/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.5898 - accuracy: 0.8031
# Epoch 40/200
# 706/706 [==============================] - 0s 75us/step - loss: 0.5657 - accuracy: 0.8088
# Epoch 41/200
# 706/706 [==============================] - 0s 87us/step - loss: 0.5667 - accuracy: 0.8074
# Epoch 42/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.5672 - accuracy: 0.8059
# Epoch 43/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.5668 - accuracy: 0.8088
# Epoch 44/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.5587 - accuracy: 0.8102
# Epoch 45/200
# 706/706 [==============================] - 0s 96us/step - loss: 0.5504 - accuracy: 0.8144
# Epoch 46/200
# 706/706 [==============================] - 0s 129us/step - loss: 0.5702 - accuracy: 0.8130
# Epoch 47/200
# 706/706 [==============================] - 0s 90us/step - loss: 0.5495 - accuracy: 0.8215
# Epoch 48/200
# 706/706 [==============================] - 0s 93us/step - loss: 0.5563 - accuracy: 0.8102
# Epoch 49/200
# 706/706 [==============================] - 0s 92us/step - loss: 0.5376 - accuracy: 0.8173
# Epoch 50/200
# 706/706 [==============================] - 0s 86us/step - loss: 0.5487 - accuracy: 0.8130
# Epoch 51/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.5459 - accuracy: 0.8130
# Epoch 52/200
# 706/706 [==============================] - 0s 88us/step - loss: 0.5289 - accuracy: 0.8144
# Epoch 53/200
# 706/706 [==============================] - 0s 100us/step - loss: 0.5419 - accuracy: 0.8201
# Epoch 54/200
# 706/706 [==============================] - 0s 119us/step - loss: 0.5258 - accuracy: 0.8229
# Epoch 55/200
# 706/706 [==============================] - 0s 99us/step - loss: 0.5216 - accuracy: 0.8201
# Epoch 56/200
# 706/706 [==============================] - 0s 151us/step - loss: 0.5232 - accuracy: 0.8159
# Epoch 57/200
# 706/706 [==============================] - 0s 102us/step - loss: 0.5466 - accuracy: 0.8144
# Epoch 58/200
# 706/706 [==============================] - 0s 63us/step - loss: 0.5165 - accuracy: 0.8215
# Epoch 59/200
# ...
# Epoch 49/200
# 707/707 [==============================] - 0s 107us/step - loss: 0.5750 - accuracy: 0.8062
# Epoch 50/200
# 707/707 [==============================] - 0s 100us/step - loss: 0.5671 - accuracy: 0.8133
# Epoch 51/200
# 707/707 [==============================] - 0s 97us/step - loss: 0.5594 - accuracy: 0.8161
# Epoch 52/200
# 707/707 [==============================] - 0s 104us/step - loss: 0.5714 - accuracy: 0.8161
# Epoch 53/200
# 707/707 [==============================] - 0s 104us/step - loss: 0.5732 - accuracy: 0.8133
# Epoch 54/200
# 707/707 [==============================] - 0s 104us/step - loss: 0.5556 - accuracy: 0.8218
# Epoch 55/200
# 707/707 [==============================] - 0s 107us/step - loss: 0.5615 - accuracy: 0.8161
# Epoch 56/200
# 707/707 [==============================] - 0s 105us/step - loss: 0.5683 - accuracy: 0.8076
# Epoch 57/200
# 707/707 [==============================] - 0s 98us/step - loss: 0.5578 - accuracy: 0.8175
# Epoch 58/200
# 707/707 [==============================] - 0s 102us/step - loss: 0.5564 - accuracy: 0.8147
# Epoch 59/200
# 707/707 [==============================] - 0s 110us/step - loss: 0.5403 - accuracy: 0.8260
# Epoch 60/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.5571 - accuracy: 0.8161
# Epoch 61/200
# 707/707 [==============================] - 0s 111us/step - loss: 0.5592 - accuracy: 0.8048
# Epoch 62/200
# 707/707 [==============================] - 0s 104us/step - loss: 0.5494 - accuracy: 0.8119
# Epoch 63/200
# 707/707 [==============================] - 0s 99us/step - loss: 0.5417 - accuracy: 0.8204
# Epoch 64/200
# 707/707 [==============================] - 0s 105us/step - loss: 0.5307 - accuracy: 0.8105
# Epoch 65/200
# 707/707 [==============================] - 0s 102us/step - loss: 0.5522 - accuracy: 0.8175
# Epoch 66/200
# 707/707 [==============================] - 0s 101us/step - loss: 0.5520 - accuracy: 0.8190
# Epoch 67/200
# 707/707 [==============================] - 0s 100us/step - loss: 0.5488 - accuracy: 0.8246
# Epoch 68/200
# 707/707 [==============================] - 0s 145us/step - loss: 0.5469 - accuracy: 0.8105
# Epoch 69/200
# 707/707 [==============================] - 0s 115us/step - loss: 0.5349 - accuracy: 0.8218
# Epoch 70/200
# 707/707 [==============================] - 0s 114us/step - loss: 0.5384 - accuracy: 0.8190
# Epoch 71/200
# 707/707 [==============================] - 0s 108us/step - loss: 0.5316 - accuracy: 0.8246
# Epoch 72/200
# 707/707 [==============================] - 0s 109us/step - loss: 0.5438 - accuracy: 0.8133
# Epoch 73/200
# 707/707 [==============================] - 0s 115us/step - loss: 0.5323 - accuracy: 0.8204
# Epoch 74/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.5264 - accuracy: 0.8232
# Epoch 75/200
# 707/707 [==============================] - 0s 110us/step - loss: 0.5251 - accuracy: 0.8232
# Epoch 76/200
# 707/707 [==============================] - 0s 99us/step - loss: 0.5252 - accuracy: 0.8260
# Epoch 77/200
# 707/707 [==============================] - 0s 103us/step - loss: 0.5283 - accuracy: 0.8190
# Epoch 78/200
# 707/707 [==============================] - 0s 132us/step - loss: 0.5237 - accuracy: 0.8175
# Epoch 79/200
# 707/707 [==============================] - 0s 100us/step - loss: 0.5174 - accuracy: 0.8147
# Epoch 80/200
# 707/707 [==============================] - 0s 216us/step - loss: 0.5066 - accuracy: 0.8246
# Epoch 81/200
# 707/707 [==============================] - 0s 94us/step - loss: 0.5237 - accuracy: 0.8190
# Epoch 82/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.5359 - accuracy: 0.8147
# Epoch 83/200
# 707/707 [==============================] - 0s 89us/step - loss: 0.5210 - accuracy: 0.8190
# Epoch 84/200
# 707/707 [==============================] - 0s 87us/step - loss: 0.5067 - accuracy: 0.8232
# Epoch 85/200
# 707/707 [==============================] - 0s 80us/step - loss: 0.5049 - accuracy: 0.8218
# Epoch 86/200
# 707/707 [==============================] - 0s 103us/step - loss: 0.5188 - accuracy: 0.8246
# Epoch 87/200
# 707/707 [==============================] - 0s 102us/step - loss: 0.5237 - accuracy: 0.8190
# Epoch 88/200
# 707/707 [==============================] - 0s 96us/step - loss: 0.5058 - accuracy: 0.8246
# Epoch 89/200
# 707/707 [==============================] - 0s 93us/step - loss: 0.4952 - accuracy: 0.8218
# Epoch 90/200
# 707/707 [==============================] - 0s 95us/step - loss: 0.4961 - accuracy: 0.8232
# Epoch 91/200
# 707/707 [==============================] - 0s 89us/step - loss: 0.4721 - accuracy: 0.8317
# Epoch 92/200
# 707/707 [==============================] - 0s 84us/step - loss: 0.5042 - accuracy: 0.8345
# Epoch 93/200
# 707/707 [==============================] - 0s 87us/step - loss: 0.5019 - accuracy: 0.8246
# Epoch 94/200
# 707/707 [==============================] - 0s 97us/step - loss: 0.4849 - accuracy: 0.8274
# Epoch 95/200
# 707/707 [==============================] - 0s 99us/step - loss: 0.4797 - accuracy: 0.8260
# Epoch 96/200
# 707/707 [==============================] - 0s 80us/step - loss: 0.4865 - accuracy: 0.8232
# Epoch 97/200
# 707/707 [==============================] - 0s 83us/step - loss: 0.5063 - accuracy: 0.8246
# Epoch 98/200
# 707/707 [==============================] - 0s 91us/step - loss: 0.4722 - accuracy: 0.8345
# Epoch 99/200
# 707/707 [==============================] - 0s 87us/step - loss: 0.4792 - accuracy: 0.8246
# Epoch 100/200
# 707/707 [==============================] - 0s 87us/step - loss: 0.4714 - accuracy: 0.8373
# Epoch 101/200
# 707/707 [==============================] - 0s 89us/step - loss: 0.4745 - accuracy: 0.8289
# Epoch 102/200
# 707/707 [==============================] - 0s 87us/step - loss: 0.4882 - accuracy: 0.8232
# Epoch 103/200
# 707/707 [==============================] - 0s 96us/step - loss: 0.4808 - accuracy: 0.8274
# Epoch 104/200
# 707/707 [==============================] - 0s 97us/step - loss: 0.4893 - accuracy: 0.8204
# Epoch 105/200
# 707/707 [==============================] - 0s 90us/step - loss: 0.4887 - accuracy: 0.8204
# Epoch 106/200
# 707/707 [==============================] - 0s 90us/step - loss: 0.4768 - accuracy: 0.8218
# Epoch 107/200
# 707/707 [==============================] - 0s 82us/step - loss: 0.4810 - accuracy: 0.8246
# Epoch 108/200
# 707/707 [==============================] - 0s 107us/step - loss: 0.4733 - accuracy: 0.8373
# Epoch 109/200
# 707/707 [==============================] - 0s 111us/step - loss: 0.4786 - accuracy: 0.8345
# Epoch 110/200
# 707/707 [==============================] - 0s 194us/step - loss: 0.4488 - accuracy: 0.8289
# Epoch 111/200
# 707/707 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.81 - 0s 142us/step - loss: 0.4761 - accuracy: 0.8260
# Epoch 112/200
# 707/707 [==============================] - 0s 193us/step - loss: 0.4779 - accuracy: 0.8246
# Epoch 113/200
# 707/707 [==============================] - 0s 165us/step - loss: 0.4694 - accuracy: 0.8345
# Epoch 114/200
# 707/707 [==============================] - 0s 100us/step - loss: 0.4937 - accuracy: 0.8232
# Epoch 115/200
# 707/707 [==============================] - 0s 102us/step - loss: 0.4556 - accuracy: 0.8331
# Epoch 116/200
# 707/707 [==============================] - 0s 92us/step - loss: 0.4684 - accuracy: 0.8317
# Epoch 117/200
# 707/707 [==============================] - 0s 113us/step - loss: 0.4891 - accuracy: 0.8190
# Epoch 118/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.4808 - accuracy: 0.8232
# Epoch 119/200
# 707/707 [==============================] - 0s 111us/step - loss: 0.4806 - accuracy: 0.8246
# Epoch 120/200
# 707/707 [==============================] - 0s 117us/step - loss: 0.4466 - accuracy: 0.8232
# Epoch 121/200
# 707/707 [==============================] - 0s 87us/step - loss: 0.4735 - accuracy: 0.8289
# Epoch 122/200
# 707/707 [==============================] - 0s 135us/step - loss: 0.4503 - accuracy: 0.8260
# Epoch 123/200
# 707/707 [==============================] - 0s 102us/step - loss: 0.4558 - accuracy: 0.8289
# Epoch 124/200
# 707/707 [==============================] - 0s 95us/step - loss: 0.4742 - accuracy: 0.8303
# Epoch 125/200
# 707/707 [==============================] - 0s 74us/step - loss: 0.4509 - accuracy: 0.8218
# Epoch 126/200
# 707/707 [==============================] - 0s 86us/step - loss: 0.4679 - accuracy: 0.8232
# Epoch 127/200
# 707/707 [==============================] - 0s 75us/step - loss: 0.4509 - accuracy: 0.8289
# Epoch 128/200
# 707/707 [==============================] - 0s 105us/step - loss: 0.4717 - accuracy: 0.8402
# Epoch 129/200
# 707/707 [==============================] - 0s 93us/step - loss: 0.4679 - accuracy: 0.8331
# Epoch 130/200
# 707/707 [==============================] - 0s 93us/step - loss: 0.4425 - accuracy: 0.8416
# Epoch 131/200
# 707/707 [==============================] - 0s 97us/step - loss: 0.4628 - accuracy: 0.8260
# Epoch 132/200
# 707/707 [==============================] - 0s 103us/step - loss: 0.4748 - accuracy: 0.8289
# Epoch 133/200
# 707/707 [==============================] - 0s 109us/step - loss: 0.4454 - accuracy: 0.8331
# Epoch 134/200
# 707/707 [==============================] - 0s 84us/step - loss: 0.4425 - accuracy: 0.8317
# Epoch 135/200
# 707/707 [==============================] - 0s 95us/step - loss: 0.4531 - accuracy: 0.8359
# Epoch 136/200
# 707/707 [==============================] - 0s 101us/step - loss: 0.4597 - accuracy: 0.8402
# Epoch 137/200
# 707/707 [==============================] - 0s 86us/step - loss: 0.4611 - accuracy: 0.8303
# Epoch 138/200
# 707/707 [==============================] - 0s 80us/step - loss: 0.4411 - accuracy: 0.8388
# Epoch 139/200
# 707/707 [==============================] - 0s 81us/step - loss: 0.4356 - accuracy: 0.8430
# Epoch 140/200
# 707/707 [==============================] - 0s 82us/step - loss: 0.4606 - accuracy: 0.8331
# Epoch 141/200
# 707/707 [==============================] - 0s 87us/step - loss: 0.4261 - accuracy: 0.8402
# Epoch 142/200
# 707/707 [==============================] - 0s 94us/step - loss: 0.4516 - accuracy: 0.8359
# Epoch 143/200
# 707/707 [==============================] - 0s 67us/step - loss: 0.4519 - accuracy: 0.8388
# Epoch 144/200
# 707/707 [==============================] - 0s 82us/step - loss: 0.4314 - accuracy: 0.8416
# Epoch 145/200
# 707/707 [==============================] - 0s 239us/step - loss: 0.4149 - accuracy: 0.8289
# Epoch 146/200
# 707/707 [==============================] - 0s 111us/step - loss: 0.4325 - accuracy: 0.8317
# Epoch 147/200
# 707/707 [==============================] - 0s 103us/step - loss: 0.4354 - accuracy: 0.8388
# Epoch 148/200
# 707/707 [==============================] - 0s 107us/step - loss: 0.4407 - accuracy: 0.8501
# Epoch 149/200
# 707/707 [==============================] - 0s 103us/step - loss: 0.4253 - accuracy: 0.8373
# Epoch 150/200
# 707/707 [==============================] - 0s 101us/step - loss: 0.4362 - accuracy: 0.8402
# Epoch 151/200
# 707/707 [==============================] - 0s 107us/step - loss: 0.4368 - accuracy: 0.8430
# Epoch 152/200
# 707/707 [==============================] - 0s 99us/step - loss: 0.4262 - accuracy: 0.8402
# Epoch 153/200
# 707/707 [==============================] - 0s 98us/step - loss: 0.4184 - accuracy: 0.8458
# Epoch 154/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.4324 - accuracy: 0.8388
# Epoch 155/200
# 707/707 [==============================] - 0s 103us/step - loss: 0.4186 - accuracy: 0.8388
# Epoch 156/200
# 707/707 [==============================] - 0s 100us/step - loss: 0.4272 - accuracy: 0.8402
# Epoch 157/200
# 707/707 [==============================] - 0s 142us/step - loss: 0.4188 - accuracy: 0.8303
# Epoch 158/200
# 707/707 [==============================] - 0s 140us/step - loss: 0.4041 - accuracy: 0.8458
# Epoch 159/200
# 707/707 [==============================] - 0s 117us/step - loss: 0.4339 - accuracy: 0.8373
# Epoch 160/200
# 707/707 [==============================] - 0s 132us/step - loss: 0.4224 - accuracy: 0.8416
# Epoch 161/200
# 707/707 [==============================] - 0s 122us/step - loss: 0.4204 - accuracy: 0.8472
# Epoch 162/200
# 707/707 [==============================] - 0s 121us/step - loss: 0.4258 - accuracy: 0.8487
# Epoch 163/200
# 707/707 [==============================] - 0s 118us/step - loss: 0.4125 - accuracy: 0.8487
# Epoch 164/200
# 707/707 [==============================] - 0s 126us/step - loss: 0.4339 - accuracy: 0.8430
# Epoch 165/200
# 707/707 [==============================] - 0s 128us/step - loss: 0.4169 - accuracy: 0.8444
# Epoch 166/200
# 707/707 [==============================] - 0s 127us/step - loss: 0.4237 - accuracy: 0.8359
# Epoch 167/200
# 707/707 [==============================] - 0s 117us/step - loss: 0.4155 - accuracy: 0.8345
# Epoch 168/200
# 707/707 [==============================] - 0s 131us/step - loss: 0.4094 - accuracy: 0.8430
# Epoch 169/200
# 707/707 [==============================] - 0s 115us/step - loss: 0.4015 - accuracy: 0.8529
# Epoch 170/200
# 707/707 [==============================] - 0s 137us/step - loss: 0.4336 - accuracy: 0.8260
# Epoch 171/200
# 707/707 [==============================] - 0s 128us/step - loss: 0.4140 - accuracy: 0.8487
# Epoch 172/200
# 707/707 [==============================] - 0s 123us/step - loss: 0.4055 - accuracy: 0.8501
# Epoch 173/200
# 707/707 [==============================] - 0s 115us/step - loss: 0.4002 - accuracy: 0.8529
# Epoch 174/200
# 707/707 [==============================] - 0s 121us/step - loss: 0.4074 - accuracy: 0.8487
# Epoch 175/200
# 707/707 [==============================] - 0s 120us/step - loss: 0.4138 - accuracy: 0.8472
# Epoch 176/200
# 707/707 [==============================] - 0s 121us/step - loss: 0.4114 - accuracy: 0.8543
# Epoch 177/200
# 707/707 [==============================] - 0s 126us/step - loss: 0.3883 - accuracy: 0.8529
# Epoch 178/200
# 707/707 [==============================] - 0s 109us/step - loss: 0.4266 - accuracy: 0.8402
# Epoch 179/200
# 707/707 [==============================] - 0s 111us/step - loss: 0.4226 - accuracy: 0.8458
# Epoch 180/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.4162 - accuracy: 0.8529
# Epoch 181/200
# 707/707 [==============================] - 0s 107us/step - loss: 0.4024 - accuracy: 0.8430
# Epoch 182/200
# 707/707 [==============================] - 0s 99us/step - loss: 0.4042 - accuracy: 0.8487
# Epoch 183/200
# 707/707 [==============================] - 0s 95us/step - loss: 0.4332 - accuracy: 0.8501
# Epoch 184/200
# 707/707 [==============================] - 0s 103us/step - loss: 0.3905 - accuracy: 0.8487
# Epoch 185/200
# 707/707 [==============================] - 0s 89us/step - loss: 0.4017 - accuracy: 0.8430
# Epoch 186/200
# 707/707 [==============================] - 0s 130us/step - loss: 0.4006 - accuracy: 0.8472
# Epoch 187/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.3955 - accuracy: 0.8458
# Epoch 188/200
# 707/707 [==============================] - 0s 107us/step - loss: 0.4201 - accuracy: 0.8444
# Epoch 189/200
# 707/707 [==============================] - 0s 100us/step - loss: 0.3957 - accuracy: 0.8515
# Epoch 190/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.4028 - accuracy: 0.8388
# Epoch 191/200
# 707/707 [==============================] - 0s 102us/step - loss: 0.3991 - accuracy: 0.8501
# Epoch 192/200
# 707/707 [==============================] - 0s 106us/step - loss: 0.3828 - accuracy: 0.8487
# Epoch 193/200
# 707/707 [==============================] - 0s 105us/step - loss: 0.4017 - accuracy: 0.8487
# Epoch 194/200
# 707/707 [==============================] - 0s 97us/step - loss: 0.4123 - accuracy: 0.8472
# Epoch 195/200
# 707/707 [==============================] - 0s 101us/step - loss: 0.3987 - accuracy: 0.8444
# Epoch 196/200
# 707/707 [==============================] - 0s 97us/step - loss: 0.3988 - accuracy: 0.8515
# Epoch 197/200
# 707/707 [==============================] - 0s 116us/step - loss: 0.3900 - accuracy: 0.8458
# Epoch 198/200
# 707/707 [==============================] - 0s 119us/step - loss: 0.4119 - accuracy: 0.8416
# Epoch 199/200
# 707/707 [==============================] - 0s 121us/step - loss: 0.4223 - accuracy: 0.8345
# Epoch 200/200
# 707/707 [==============================] - 0s 111us/step - loss: 0.4049 - accuracy: 0.8458
# 78/78 [==============================] - 0s 2ms/step

# %% [markdown]
# ## XGBoost Classifier:
#
# XGBoost (eXtreme Gradient Boosting) is an advanced implementation of gradient boosting algorithm. It's a powerful machine learning algorithm especially where speed and accuracy are concerned. This model requires parameter tuning to improve and fully leverage its advantages over other algorithms. Following parameters were taken into consideration from XGBoost documentation:
#
# max_depth: Maximum depth of a tree. Increasing this value will make the model more complex and more likely to overfit.
# objective: multi:softmax: set XGBoost to do multiclass classification, also need to set num_class(number of classes)
# subsample: corresponds to the fraction of observations (the rows) to subsample at each step.
# eta: learning_rate or step size shrinkage used in update to prevents overfitting. After each boosting step, we can directly get the weights of new features, and eta shrinks the feature weights to make the boosting process more conservative.

# %%
from xgboost import XGBClassifier

# Create a classifier using best params
xgb = XGBClassifier(booster='gbtree', objective='multi:softmax', max_depth = 11, n_estimators = 35,
                    eta = 0.1, subsample  = 0.7, num_class = 4, random_state=42)
# Fit the classifier with the training data
xgb.fit(X_train,y_train)
# Use trained model to predict output of test dataset
y_pred = xgb.predict(X_test)

accuracies[5] = accuracy_score(y_test, y_pred)
auc_roc[5] = multiclass_roc_auc_score(y_test, y_pred)

print('CLASSIFICATION REPORT for XGBoost classifier... \n')
print(classification_report(y_test,y_pred))
print('\nCONFUSION MATRIX for XGBoost classifier... \n')
confusion_matrix(y_test,y_pred)
# Out:
# CLASSIFICATION REPORT for XGBoost classifier...
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.99      0.95        87
#          1.0       0.80      0.85      0.82        46
#          2.0       0.62      0.40      0.48        20
#          3.0       0.00      0.00      0.00         4
#
#     accuracy                           0.85       157
#    macro avg       0.58      0.56      0.56       157
# weighted avg       0.81      0.85      0.83       157
#
#
# CONFUSION MATRIX for XGBoost classifier...
# C:\Users\HOME\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# array([[86,  0,  1,  0],
#        [ 4, 39,  3,  0],
#        [ 4,  8,  8,  0],
#        [ 1,  2,  1,  0]], dtype=int64)

# %% [markdown]
# ## Results
# In summary, the following six machine learning models were developed to classify Autism using 13 selected features from the ABIDE dataset and reducing the subjects to 785. Highest accuracy (84.71 %) and ROC_AUC score (0.74) was achieved by XGBoost algorithm, followed by Random Forest which too was pretty close. The classification report and confusion matrix of the best model is given above.

# %%
models = {'Classifiers': model_name, 'Accuracy score': accuracies, 'AUC-ROC Score': auc_roc}
models_df = pd.DataFrame(models, columns = ['Classifiers', 'Accuracy score', 'AUC-ROC Score'] )
models_df
# Out:
#            Classifiers  Accuracy score AUC-ROC Score
# 0        Random Forest        0.840764      0.735244
# 1  Logistic Regression        0.668790      0.599839
# 2                  kNN        0.687898      0.619831
# 3              SVM_rbf        0.796178      0.694598
# 4                  ANN        0.811441
# 5              XGBoost        0.847134      0.747647
